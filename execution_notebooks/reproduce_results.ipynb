# %% [markdown]
# # Reproduce results
# Rebuilds every table and figure from the cached LLM responses. **No API keys needed.** Runtime → Run all.

# %%
# Setup (skip the clone if running locally inside the repo)
import os
if not os.path.exists('phase_pipeline'):
    # !git clone https://github.com/YOURUSERNAME/YOURREPO.git
    # %cd YOURREPO
# !pip install -q -r requirements.txt
# %load_ext autoreload
# %autoreload 2

# %%
from phase_pipeline.llm_client import load_cached
from phase_pipeline.compare import parse_verdict
from phase_pipeline.bradley_terry import estimate_scores, rank_parties
from phase_pipeline.validate import spearman_validation, binary_winner, positional_error

raw = load_cached('comparisons')
print(f'{len(raw)} cached comparison responses loaded')

# %%
# TODO: filter raw responses by election/condition, parse verdicts,
# estimate Bradley-Terry scores, and regenerate each dissertation table.
# verdicts = [parse_verdict(r) for r in raw]
# scores = estimate_scores(verdicts_2017, parties_2017, alpha=0.1)
# spearman_validation(scores, vote_shares_2017)
